# %%
import pandas as pd
df = pd.read_csv ('AllMonths_RAW.csv')
json = df.to_json ('AllMonths_RAW.json')
json

# %%
df.head()
# Out:
#    YEAR  MONTH  DAY_OF_WEEK                FL_DATE OP_UNIQUE_CARRIER TAIL_NUM  \
# 0  2022      1            3  1/12/2022 12:00:00 AM                YX   N420YX
# 1  2022      1            4  1/13/2022 12:00:00 AM                YX   N124HQ
# 2  2022      1            5  1/14/2022 12:00:00 AM                YX   N425YX
# 3  2022      1            7  1/16/2022 12:00:00 AM                YX   N106HQ
# 4  2022      1            1  1/17/2022 12:00:00 AM                YX   N450YX
#
#    OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  ...  CRS_ARR_TIME  ARR_TIME  \
# 0               4904    LGA  BNA           620  ...           807     748.0
# 1               4904    LGA  BNA           620  ...           807     745.0
# 2               4904    LGA  BNA           620  ...           807     800.0
# 3               4904    LGA  BNA           620  ...           807     746.0
# 4               4904    LGA  BNA           620  ...           807     755.0
#
# ...

# %%
print(json)
# Out:
# None

# %%
import pandas as pd
df = pd.read_csv ('AllMonths_RAW.csv')
short_df = df.head(100)
short_df
# Out:
#     YEAR  MONTH  DAY_OF_WEEK                FL_DATE OP_UNIQUE_CARRIER  \
# 0   2022      1            3  1/12/2022 12:00:00 AM                YX
# 1   2022      1            4  1/13/2022 12:00:00 AM                YX
# 2   2022      1            5  1/14/2022 12:00:00 AM                YX
# 3   2022      1            7  1/16/2022 12:00:00 AM                YX
# 4   2022      1            1  1/17/2022 12:00:00 AM                YX
# ..   ...    ...          ...                    ...               ...
# 95  2022      1            4   1/6/2022 12:00:00 AM                YX
# 96  2022      1            6   1/8/2022 12:00:00 AM                YX
# 97  2022      1            7   1/9/2022 12:00:00 AM                YX
# 98  2022      1            1  1/10/2022 12:00:00 AM                YX
# 99  2022      1            2  1/11/2022 12:00:00 AM                YX
#
#    TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  ...  CRS_ARR_TIME  \
# ...

# %%
short_df.to_json ('AllMonths_RAW_Short.json')

# %%
import pandas as pd
df = pd.read_csv ('AllMonths_RAW.csv')

# %%
print(df.columns)
# Out:
# Index(['YEAR', 'MONTH', 'DAY_OF_WEEK', 'FL_DATE', 'OP_UNIQUE_CARRIER',
#        'TAIL_NUM', 'OP_CARRIER_FL_NUM', 'ORIGIN', 'DEST', 'CRS_DEP_TIME',
#        'DEP_TIME', 'DEP_DELAY', 'DEP_DEL15', 'DEP_TIME_BLK', 'TAXI_OUT',
#        'WHEELS_OFF', 'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME',
#        'ARR_DELAY', 'ARR_DEL15', 'ARR_TIME_BLK', 'CANCELLED',
#        'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'DISTANCE'],
#       dtype='object')
