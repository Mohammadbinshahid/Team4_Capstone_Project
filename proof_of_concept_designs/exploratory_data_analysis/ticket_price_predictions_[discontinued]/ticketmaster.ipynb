# %%
# Dependencies and Setup
import pandas as pd
import requests

# Import API key
from config import tm_key

# %%
sba = "venueId=Zkr9jZdAeL&"
tml = "attractionId=K8vZ9171o80&"
resale = "source=tmr&"
nhl = "embeddedName=NHL&"
params =  resale+nhl

# %%
print(params)
# Out:
# source=tmr&embeddedName=NHL&

# %% [markdown]
# ## Event details call

# %%
tm_url = "https://app.ticketmaster.com/discovery/v2/events.json?" + params + "apikey=" + tm_key

# %%
tm_response = requests.get(tm_url)

# %%
print(tm_response)
# Out:
# <Response [200]>

# %%
ticket_master_response.json()
# Out:
# {'_embedded': {'events': [{'name': 'Toronto Raptors vs. Philadelphia 76ers',
#     'type': 'event',
#     'id': 'Z7r9jZ1Ad4w84',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/event/Z7r9jZ1Ad4w84',
#     'locale': 'en-us',
#     'images': [{'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/810/587e669b-5946-46c0-a526-b63b6e008810_1339651_TABLET_LANDSCAPE_16_9.jpg',
#       'width': 1024,
#       'height': 576,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/810/587e669b-5946-46c0-a526-b63b6e008810_1339651_RETINA_LANDSCAPE_16_9.jpg',
#       'width': 1136,
#       'height': 639,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/810/587e669b-5946-46c0-a526-b63b6e008810_1339651_TABLET_LANDSCAPE_3_2.jpg',
#       'width': 1024,
#       'height': 683,
#       'fallback': False},
#      {'ratio': '4_3',
# ...

# %%
print(params)
# Out:
# venueId=Zkr9jZdAeL&attractionId=K8vZ9171o80&

# %%
print(tm_url)
# Out:
# https://app.ticketmaster.com/discovery/v2/classifications.json?venueId=Zkr9jZdAeL&attractionId=K8vZ9171o80&apikey=pYWAsgIIHc6dcHSdNtSGEgfwROjBRa04

# %% [markdown]
# ## Event search call

# %%
event = "/G5vZZ98OmFaIf"

# %%
tm_event_url = "https://app.ticketmaster.com/discovery/v2/events" + event + ".json?apikey=" + tm_key

# %%
tm_event_response = requests.get(tm_event_url)

# %%
print(tm_event_response)
# Out:
# <Response [200]>

# %%
tm_event_response.json()
# Out:
# {'name': 'Toronto Maple Leafs vs. Ottawa Senators',
#  'type': 'event',
#  'id': 'G5vZZ98OmFaIf',
#  'test': False,
#  'url': 'https://www.ticketmaster.ca/toronto-maple-leafs-vs-ottawa-senators-toronto-ontario-09-24-2022/event/10005D082E209A14',
#  'locale': 'en-us',
#  'images': [{'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/2d9/2f921db0-3766-4ceb-b1a8-597b8cc672d9_1277181_EVENT_DETAIL_PAGE_16_9.jpg',
#    'width': 205,
#    'height': 115,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/2d9/2f921db0-3766-4ceb-b1a8-597b8cc672d9_1277181_RECOMENDATION_16_9.jpg',
#    'width': 100,
#    'height': 56,
#    'fallback': False},
#   {'ratio': '4_3',
#    'url': 'https://s1.ticketm.net/dam/a/2d9/2f921db0-3766-4ceb-b1a8-597b8cc672d9_1277181_CUSTOM.jpg',
#    'width': 305,
#    'height': 225,
#    'fallback': False},
#   {'ratio': '3_2',
# ...

# %% [markdown]
# ## Classifications call

# %%
event = "/KZFzBErXgnZfZ7vA7d"

# %%
tm_classification_url = "https://app.ticketmaster.com/discovery/v2/classifications.json?" + params + "apikey=" + tm_key

# %%
tm_classification_response = requests.get(tm_classification_url)

# %%
print(tm_classification_response)
# Out:
# <Response [200]>

# %%
tm_classification_response.json()
# Out:
# {'_embedded': {'classifications': [{'family': False,
#     '_links': {'self': {'href': '/discovery/v2/classifications/KZFzniwnSyZfZ7v7n1?locale=en-us'}},
#     'segment': {'id': 'KZFzniwnSyZfZ7v7n1',
#      'name': 'Miscellaneous',
#      'locale': 'en-us',
#      'primaryId': 'dataAdmin-segment-00000000000003e9',
#      '_links': {'self': {'href': '/discovery/v2/classifications/segments/KZFzniwnSyZfZ7v7n1?locale=en-us'}},
#      '_embedded': {'genres': [{'id': 'KnvZfZ7vAAa',
#         'name': 'Casino/Gaming',
#         'locale': 'en-us',
#         '_links': {'self': {'href': '/discovery/v2/classifications/genres/KnvZfZ7vAAa?locale=en-us'}},
#         '_embedded': {'subgenres': [{'id': 'KZazBEonSMnZfZ7vFnt',
#            'name': 'Casino/Gaming',
#            'locale': 'en-us',
#            '_links': {'self': {'href': '/discovery/v2/classifications/subgenres/KZazBEonSMnZfZ7vFnt?locale=en-us'}}}]}},
#        {'id': 'KnvZfZ7vAA1',
#         'name': 'Comedy',
# ...
